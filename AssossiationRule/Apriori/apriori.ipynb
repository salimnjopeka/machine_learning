# %% [markdown]
# # Apriori

# %% [markdown]
# ## Importing Libraries

# %%
# %pip install apyori -i https://pypi.org/simple
# Out:
# Collecting apyori
#   Using cached apyori-1.1.2-py3-none-any.whl
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %% [markdown]
# ## Training the Apriori model on the dataset

# %%
from apyori import apriori

rules = apriori(transactions = transactions, min_suPport = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %% [markdown]
# # Visualizing the test results

# %% [markdown]
# ## Displaying the first result coming directly from the output of the apriori function

# %%
results = list(rules)
results
# Out:
# []

# %% [markdown]
# ## Putting the results well organized into a Pandas DataFrame

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %% [markdown]
# ## Displaying the reults non sorted

# %%
resultsinDataFrame
# Out:
# Empty DataFrame
# Columns: [Left Hand Side, Right Hand Side, Support, Confidence, Lift]
# Index: []

# %% [markdown]
# ## Displaying the results sorted by descending lifts

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
#
# File c:\Users\ADMIN\Documents\MachineLearning\.venv\Lib\site-packages\pandas\core\frame.py:7666, in DataFrame.nlargest(self, n, columns, keep)
#    7547 def nlargest(
#    7548     self, n: int, columns: IndexLabel, keep: NsmallestNlargestKeep = "first"
#    7549 ) -> DataFrame:
#    7550     """
#    7551     Return the first `n` rows ordered by `columns` in descending order.
#    7552
#    (...)   7664     Brunei      434000    12128      BN
#    7665     """
# -> 7666     return selectn.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#
# File c:\Users\ADMIN\Documents\MachineLearning\.venv\Lib\site-packages\pandas\core\methods\selectn.py:57, in SelectN.nlargest(self)
#      55 @final
#      56 def nlargest(self):
# ---> 57     return self.compute("nlargest")
#
# File c:\Users\ADMIN\Documents\MachineLearning\.venv\Lib\site-packages\pandas\core\methods\selectn.py:201, in SelectNFrame.compute(self, method)
#     199     dtype = frame[column].dtype
#     200     if not self.is_valid_dtype_n_method(dtype):
# --> 201         raise TypeError(
#     202             f"Column {repr(column)} has dtype {dtype}, "
#     203             f"cannot use method {repr(method)} with this dtype"
#     204         )
#     206 def get_indexer(current_indexer, other_indexer):
#     207     """
#     208     Helper function to concat `current_indexer` and `other_indexer`
#     209     depending on `method`
#     210     """
#
# TypeError: Column 'Lift' has dtype object, cannot use method 'nlargest' with this dtype
