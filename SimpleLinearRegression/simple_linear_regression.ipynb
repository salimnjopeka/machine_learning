# %% [markdown]
# Simple Linear Regression

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

data_path = Path(r'c:\Users\ADMIN\Documents\MachineLearning\salary_data.csv')
dataset = pd.read_csv(data_path)

# %% [markdown]
# # Importing Dataset

# %%
data_path = Path(r'c:\Users\ADMIN\Documents\MachineLearning\salary_data.csv')
dataset = pd.read_csv(data_path)
dataset = dataset.drop(columns=['Age', 'Gender', 'Education Level', 'Job Title'])
dataset = dataset.dropna()
print('Data', dataset.isnull().sum())
# Out:
# Data Years of Experience    0
# Salary                 0
# dtype: int64

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
print(X)
print(y)
# Out:
# [[ 5. ]
#  [ 3. ]
#  [15. ]
#  [ 7. ]
#  [20. ]
#  [ 2. ]
#  [12. ]
#  [ 4. ]
#  [ 1. ]
#  [10. ]
#  [ 3. ]
#  [18. ]
#  [ 6. ]
#  [14. ]
#  [ 2. ]
#  [16. ]
#  [ 7. ]
#  [12. ]
#  [ 0. ]
#  [22. ]
#  [ 5. ]
#  [19. ]
#  [ 2. ]
#  [ 9. ]
#  [13. ]
#  [ 3. ]
#  [11. ]
#  [ 1. ]
#  [15. ]
#  [ 6. ]
#  [25. ]
#  [ 4. ]
#  [ 3. ]
#  [10. ]
#  [20. ]
#  [ 2. ]
#  [ 7. ]
#  [14. ]
#  [ 1. ]
#  [21. ]
#  [ 5. ]
#  [18. ]
#  [ 3. ]
#  [ 8. ]
#  [13. ]
#  [ 2. ]
#  [ 5. ]
#  [16. ]
#  [11. ]
#  [ 0. ]
#  [22. ]
#  [ 7. ]
#  [12. ]
#  [19. ]
#  [ 3. ]
#  [ 9. ]
#  [ 2. ]
#  [17. ]
#  [ 4. ]
#  [ 7. ]
#  [23. ]
#  [ 3. ]
#  [12. ]
#  [21. ]
#  [ 1. ]
#  [10. ]
#  [19. ]
#  [ 5. ]
#  [ 8. ]
#  [18. ]
#  [ 6. ]
#  [11. ]
#  [16. ]
#  [ 2. ]
#  [14. ]
#  [10. ]
#  [22. ]
#  [ 6. ]
#  [20. ]
#  [ 3. ]
#  [ 8. ]
#  [13. ]
#  [ 0. ]
#  [24. ]
#  [ 2. ]
#  [10. ]
#  [ 2. ]
#  [15. ]
#  [21. ]
#  [ 6. ]
#  [11. ]
#  [ 3. ]
#  [18. ]
#  [25. ]
#  [ 7. ]
#  [12. ]
#  [22. ]
#  [ 1. ]
#  [10. ]
#  [20. ]
# ...

# %% [markdown]
# # Splitting dataset into Training set and Test set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Training the Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# # Visualising the Training set results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Visualising the Test set results

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Making a single prediction (for exemple the salary of a person having 12 years of experience)

# %%
print(regressor.predict([[12]]))
# Out:
# [113966.43937145]

# %% [markdown]
# # Getting the final linear regression equation with the values of the coefficients

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [6884.79101577]
# 31348.947182205826
